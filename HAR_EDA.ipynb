# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('/home/ml2/rail_project/amalproject/activity/UCI_HAR_Dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('/home/ml2/rail_project/amalproject/activity/UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('/home/ml2/rail_project/amalproject/activity/UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
# /home/ml2/rail_project/image-segmentation-keras-Amal/venv3/lib/python3.5/site-packages/pandas/io/parsers.py:702: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 4808            0.25291          -0.029169          -0.128313
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 4808         -0.411681         -0.268524          0.078616         -0.428023
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 4808         -0.394679          0.090804         -0.248862  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 4808                     0.197388                             -0.868587
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 4808                         -0.698396                              0.037019
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 4808             -0.789829              0.200151              0.125331
#
#       subject  Activity  ActivityName
# 4808       23         1       WALKING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('/home/ml2/rail_project/amalproject/activity/UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('/home/ml2/rail_project/amalproject/activity/UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('/home/ml2/rail_project/amalproject/activity/UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1764           0.282221          -0.016711          -0.106459
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1764         -0.996784         -0.991911         -0.996995         -0.997131
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1764         -0.990749         -0.996808         -0.940622  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1764                    -0.324958                              0.685271
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1764                           0.92547                              0.152943
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1764              0.348986             -0.776023              -0.14071
#
#       subject  Activity  ActivityName
# 1764       13         6        LAYING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1",desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.99,13), xytext=(-0.5,10), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.185s...
# [t-SNE] Computed neighbors for 7352 samples in 27.496s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.085s
# [t-SNE] Iteration 50: error = 124.7924271, gradient norm = 0.0252035 (50 iterations in 2.424s)
# [t-SNE] Iteration 100: error = 107.4286423, gradient norm = 0.0290656 (50 iterations in 1.782s)
# [t-SNE] Iteration 150: error = 100.9970093, gradient norm = 0.0209683 (50 iterations in 1.464s)
# [t-SNE] Iteration 200: error = 97.6057816, gradient norm = 0.0177515 (50 iterations in 1.409s)
# [t-SNE] Iteration 250: error = 95.3063812, gradient norm = 0.0141239 (50 iterations in 1.394s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.306381
# [t-SNE] Iteration 300: error = 4.1181335, gradient norm = 0.0015596 (50 iterations in 1.325s)
# [t-SNE] Iteration 350: error = 3.2097223, gradient norm = 0.0009979 (50 iterations in 1.312s)
# [t-SNE] Iteration 400: error = 2.7808881, gradient norm = 0.0007139 (50 iterations in 1.344s)
# [t-SNE] Iteration 450: error = 2.5176487, gradient norm = 0.0005700 (50 iterations in 1.353s)
# [t-SNE] Iteration 500: error = 2.3349824, gradient norm = 0.0004753 (50 iterations in 1.360s)
# [t-SNE] Iteration 550: error = 2.1969786, gradient norm = 0.0004218 (50 iterations in 1.357s)
# [t-SNE] Iteration 600: error = 2.0878797, gradient norm = 0.0003701 (50 iterations in 1.364s)
# [t-SNE] Iteration 650: error = 1.9982502, gradient norm = 0.0003297 (50 iterations in 1.363s)
# [t-SNE] Iteration 700: error = 1.9225992, gradient norm = 0.0003036 (50 iterations in 1.363s)
# [t-SNE] Iteration 750: error = 1.8578062, gradient norm = 0.0002769 (50 iterations in 1.362s)
# [t-SNE] Iteration 800: error = 1.8011097, gradient norm = 0.0002561 (50 iterations in 1.362s)
# [t-SNE] Iteration 850: error = 1.7510685, gradient norm = 0.0002377 (50 iterations in 1.365s)
# [t-SNE] Iteration 900: error = 1.7063907, gradient norm = 0.0002250 (50 iterations in 1.365s)
# [t-SNE] Iteration 950: error = 1.6662079, gradient norm = 0.0002123 (50 iterations in 1.365s)
# [t-SNE] Iteration 1000: error = 1.6298671, gradient norm = 0.0001997 (50 iterations in 1.363s)
# [t-SNE] KL divergence after 1000 iterations: 1.629867
# Done..
# Creating plot for this t-sne visualization..
# /home/ml2/rail_project/image-segmentation-keras-Amal/venv3/lib/python3.5/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.142s...
# [t-SNE] Computed neighbors for 7352 samples in 27.977s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.050s
# [t-SNE] Iteration 50: error = 114.1007538, gradient norm = 0.0197520 (50 iterations in 2.637s)
# [t-SNE] Iteration 100: error = 97.7155762, gradient norm = 0.0167325 (50 iterations in 1.667s)
# [t-SNE] Iteration 150: error = 93.3423233, gradient norm = 0.0107460 (50 iterations in 1.417s)
# [t-SNE] Iteration 200: error = 91.3111420, gradient norm = 0.0062492 (50 iterations in 1.384s)
# [t-SNE] Iteration 250: error = 90.0990143, gradient norm = 0.0048809 (50 iterations in 1.379s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.099014
# [t-SNE] Iteration 300: error = 3.5805280, gradient norm = 0.0014673 (50 iterations in 1.321s)
# [t-SNE] Iteration 350: error = 2.8206196, gradient norm = 0.0007466 (50 iterations in 1.303s)
# [t-SNE] Iteration 400: error = 2.4378724, gradient norm = 0.0005225 (50 iterations in 1.322s)
# [t-SNE] Iteration 450: error = 2.2194958, gradient norm = 0.0004084 (50 iterations in 1.328s)
# [t-SNE] Iteration 500: error = 2.0743084, gradient norm = 0.0003334 (50 iterations in 1.332s)
# [t-SNE] Iteration 550: error = 1.9686611, gradient norm = 0.0002863 (50 iterations in 1.344s)
# [t-SNE] Iteration 600: error = 1.8872980, gradient norm = 0.0002461 (50 iterations in 1.352s)
# [t-SNE] Iteration 650: error = 1.8219504, gradient norm = 0.0002182 (50 iterations in 1.358s)
# [t-SNE] Iteration 700: error = 1.7679507, gradient norm = 0.0001977 (50 iterations in 1.366s)
# [t-SNE] Iteration 750: error = 1.7223148, gradient norm = 0.0001812 (50 iterations in 1.370s)
# [t-SNE] Iteration 800: error = 1.6834978, gradient norm = 0.0001647 (50 iterations in 1.377s)
# [t-SNE] Iteration 850: error = 1.6497568, gradient norm = 0.0001529 (50 iterations in 1.378s)
# [t-SNE] Iteration 900: error = 1.6201446, gradient norm = 0.0001428 (50 iterations in 1.382s)
# [t-SNE] Iteration 950: error = 1.5939676, gradient norm = 0.0001334 (50 iterations in 1.382s)
# [t-SNE] Iteration 1000: error = 1.5705318, gradient norm = 0.0001242 (50 iterations in 1.384s)
# [t-SNE] KL divergence after 1000 iterations: 1.570532
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# /home/ml2/rail_project/image-segmentation-keras-Amal/venv3/lib/python3.5/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.141s...
# [t-SNE] Computed neighbors for 7352 samples in 28.381s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.092s
# [t-SNE] Iteration 50: error = 105.3966370, gradient norm = 0.0270045 (50 iterations in 2.737s)
# [t-SNE] Iteration 100: error = 90.5018082, gradient norm = 0.0085081 (50 iterations in 1.832s)
# [t-SNE] Iteration 150: error = 87.3163147, gradient norm = 0.0063009 (50 iterations in 1.502s)
# [t-SNE] Iteration 200: error = 86.0760117, gradient norm = 0.0032429 (50 iterations in 1.469s)
# [t-SNE] Iteration 250: error = 85.3801651, gradient norm = 0.0031719 (50 iterations in 1.453s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.380165
# [t-SNE] Iteration 300: error = 3.1354668, gradient norm = 0.0013871 (50 iterations in 1.391s)
# [t-SNE] Iteration 350: error = 2.4931278, gradient norm = 0.0006463 (50 iterations in 1.367s)
# [t-SNE] Iteration 400: error = 2.1742034, gradient norm = 0.0004219 (50 iterations in 1.381s)
# [t-SNE] Iteration 450: error = 1.9897976, gradient norm = 0.0003124 (50 iterations in 1.386s)
# [t-SNE] Iteration 500: error = 1.8715490, gradient norm = 0.0002502 (50 iterations in 1.397s)
# [t-SNE] Iteration 550: error = 1.7880667, gradient norm = 0.0002097 (50 iterations in 1.405s)
# [t-SNE] Iteration 600: error = 1.7258545, gradient norm = 0.0001820 (50 iterations in 1.412s)
# [t-SNE] Iteration 650: error = 1.6770103, gradient norm = 0.0001603 (50 iterations in 1.416s)
# [t-SNE] Iteration 700: error = 1.6376845, gradient norm = 0.0001423 (50 iterations in 1.416s)
# [t-SNE] Iteration 750: error = 1.6050538, gradient norm = 0.0001294 (50 iterations in 1.416s)
# [t-SNE] Iteration 800: error = 1.5776922, gradient norm = 0.0001180 (50 iterations in 1.415s)
# [t-SNE] Iteration 850: error = 1.5542192, gradient norm = 0.0001093 (50 iterations in 1.416s)
# [t-SNE] Iteration 900: error = 1.5338984, gradient norm = 0.0001009 (50 iterations in 1.416s)
# [t-SNE] Iteration 950: error = 1.5159800, gradient norm = 0.0000950 (50 iterations in 1.412s)
# [t-SNE] Iteration 1000: error = 1.5003946, gradient norm = 0.0000909 (50 iterations in 1.417s)
# [t-SNE] KL divergence after 1000 iterations: 1.500395
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# /home/ml2/rail_project/image-segmentation-keras-Amal/venv3/lib/python3.5/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.141s...
# [t-SNE] Computed neighbors for 7352 samples in 28.838s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.175s
# [t-SNE] Iteration 50: error = 97.9168015, gradient norm = 0.0133140 (50 iterations in 3.068s)
# [t-SNE] Iteration 100: error = 83.8711700, gradient norm = 0.0066420 (50 iterations in 2.056s)
# [t-SNE] Iteration 150: error = 81.9012756, gradient norm = 0.0039843 (50 iterations in 1.849s)
# [t-SNE] Iteration 200: error = 81.1879120, gradient norm = 0.0025099 (50 iterations in 1.823s)
# [t-SNE] Iteration 250: error = 80.7915726, gradient norm = 0.0022701 (50 iterations in 1.798s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.791573
# [t-SNE] Iteration 300: error = 2.7105970, gradient norm = 0.0013048 (50 iterations in 1.566s)
# [t-SNE] Iteration 350: error = 2.1758847, gradient norm = 0.0005809 (50 iterations in 1.506s)
# [t-SNE] Iteration 400: error = 1.9249907, gradient norm = 0.0003494 (50 iterations in 1.505s)
# [t-SNE] Iteration 450: error = 1.7777791, gradient norm = 0.0002480 (50 iterations in 1.522s)
# [t-SNE] Iteration 500: error = 1.6833230, gradient norm = 0.0001930 (50 iterations in 1.539s)
# [t-SNE] Iteration 550: error = 1.6184467, gradient norm = 0.0001590 (50 iterations in 1.554s)
# [t-SNE] Iteration 600: error = 1.5711236, gradient norm = 0.0001342 (50 iterations in 1.560s)
# [t-SNE] Iteration 650: error = 1.5351526, gradient norm = 0.0001182 (50 iterations in 1.568s)
# [t-SNE] Iteration 700: error = 1.5071726, gradient norm = 0.0001042 (50 iterations in 1.581s)
# [t-SNE] Iteration 750: error = 1.4846869, gradient norm = 0.0000962 (50 iterations in 1.585s)
# [t-SNE] Iteration 800: error = 1.4663802, gradient norm = 0.0000909 (50 iterations in 1.587s)
# [t-SNE] Iteration 850: error = 1.4513773, gradient norm = 0.0000818 (50 iterations in 1.589s)
# [t-SNE] Iteration 900: error = 1.4385666, gradient norm = 0.0000773 (50 iterations in 1.594s)
# [t-SNE] Iteration 950: error = 1.4279274, gradient norm = 0.0000756 (50 iterations in 1.599s)
# [t-SNE] Iteration 1000: error = 1.4193314, gradient norm = 0.0000705 (50 iterations in 1.607s)
# [t-SNE] KL divergence after 1000 iterations: 1.419331
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# /home/ml2/rail_project/image-segmentation-keras-Amal/venv3/lib/python3.5/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.142s...
# [t-SNE] Computed neighbors for 7352 samples in 29.682s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.432s
# [t-SNE] Iteration 50: error = 86.5470734, gradient norm = 0.0203452 (50 iterations in 2.986s)
# [t-SNE] Iteration 100: error = 75.5864487, gradient norm = 0.0059906 (50 iterations in 2.418s)
# [t-SNE] Iteration 150: error = 74.6227798, gradient norm = 0.0066907 (50 iterations in 2.109s)
# [t-SNE] Iteration 200: error = 74.2491379, gradient norm = 0.0019776 (50 iterations in 2.062s)
# [t-SNE] Iteration 250: error = 74.0652618, gradient norm = 0.0012814 (50 iterations in 2.055s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.065262
# [t-SNE] Iteration 300: error = 2.1506124, gradient norm = 0.0011817 (50 iterations in 1.925s)
# [t-SNE] Iteration 350: error = 1.7533401, gradient norm = 0.0004820 (50 iterations in 1.836s)
# [t-SNE] Iteration 400: error = 1.5850646, gradient norm = 0.0002786 (50 iterations in 1.834s)
# [t-SNE] Iteration 450: error = 1.4916917, gradient norm = 0.0001885 (50 iterations in 1.844s)
# [t-SNE] Iteration 500: error = 1.4319056, gradient norm = 0.0001400 (50 iterations in 1.858s)
# [t-SNE] Iteration 550: error = 1.3910745, gradient norm = 0.0001111 (50 iterations in 1.866s)
# [t-SNE] Iteration 600: error = 1.3618531, gradient norm = 0.0000933 (50 iterations in 1.869s)
# [t-SNE] Iteration 650: error = 1.3406948, gradient norm = 0.0000804 (50 iterations in 1.882s)
# [t-SNE] Iteration 700: error = 1.3247952, gradient norm = 0.0000715 (50 iterations in 1.884s)
# [t-SNE] Iteration 750: error = 1.3128062, gradient norm = 0.0000670 (50 iterations in 1.894s)
# [t-SNE] Iteration 800: error = 1.3035750, gradient norm = 0.0000617 (50 iterations in 1.906s)
# [t-SNE] Iteration 850: error = 1.2962552, gradient norm = 0.0000591 (50 iterations in 1.905s)
# [t-SNE] Iteration 900: error = 1.2907197, gradient norm = 0.0000567 (50 iterations in 1.901s)
# [t-SNE] Iteration 950: error = 1.2862406, gradient norm = 0.0000548 (50 iterations in 1.904s)
# [t-SNE] Iteration 1000: error = 1.2823908, gradient norm = 0.0000504 (50 iterations in 1.907s)
# [t-SNE] KL divergence after 1000 iterations: 1.282391
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# /home/ml2/rail_project/image-segmentation-keras-Amal/venv3/lib/python3.5/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
